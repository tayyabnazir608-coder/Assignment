# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name:\tTayyab Nazir")
print("Father Name:\tMuhammad Nazir")
print("Date of Birth:\t01-01-2007")
# Out:
# Name:	Tayyab Nazir
# Father Name:	Muhammad Nazir
# Date of Birth:	01-01-2007

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Tayyab Nazir"
father = "Muhammad Nazir"
age = 15
city = "Karachi"
education = "Matriculation"
print("My name is", name)
print("My father's name is", father)
print("I am", age, "years old.")
print("I live in", city)
print("I am studying", education)
# Out:
# My name is Tayyab Nazir
# My father's name is Muhammad Nazir
# I am 15 years old.
# I live in Karachi
# I am studying Matriculation

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 20
b = 10
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a > b)
print(a < b)
print(a == b)
print(a != b)
c = a
c += 5
print(c)
print((a > b) and (b < a))
print((a < b) or (a > b))
print(not(a == b))
numbers = [10, 20, 30]
print(20 in numbers)
print(50 not in numbers)
print(a is b)
print(a is not b)
# Out:
# 30
# 10
# 200
# 2.0
# 0
# True
# False
# False
# True
# 25
# True
# True
# True
# True
# True
# False
# True

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
english = int(input("Enter English Marks"))
islamiat = int(input("Enter Islamiat Marks"))
maths = int(input("Enter Maths Marks"))
total_marks = 300
obtained_marks = english + islamiat + maths
percentage = (obtained_marks / total_marks) * 100
print("Percentage =",percentage)
# Out:
# Percentage = 80.0
